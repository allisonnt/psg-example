# %% [markdown]
# # Variables de contexto claro
#
# ☝️ Es recomendable utilizar nombres de variables que contengan un contexto claro y describan lo que representan

# %%
print (type (1))

x1q3z9ahd = 35.0
x1q3z9afd = 12.50
x1q3p9afd = x1q3z9ahd * x1q3z9afd
print (x1q3p9afd)
# Out:
# <class 'int'>
# 437.5

# %% [markdown]
# # Números Enteros
# ## Integers - int
# - Son números sin parte decimal.
#
# - Pueden ser positivos, negativos o cero.
#
# - Tienen precisión ilimitada, pueden representar números muy grandes o muy pequeños sin perder exactitud.
#
#  👉                     **Z={...,−3,−2,−1,0,1,2,3,...}**

# %%
print (10)
print (type(10))

# como declarar un numero entero
variable = 100
print (variable)
print (type(variable))

# se puede declarar usando la funcion "int"
variable_2 = int(20.0)
print (variable_2)
print (type(variable_2))
# Out:
# 10
# <class 'int'>
# 100
# <class 'int'>
# 20
# <class 'int'>

# %% [markdown]
# # Declarando números enteros en otras bases numéricas
#  Base	    Prefijo	    Símbolos válidos     ejemplo
# Decimal	    (ninguno)	       0–9	            10
# Binario	        0b	           0, 1	           0b1010
# Octal	        0o	           0–7	            0o12
# Hexadecimal 	0x	          0–9, a–f	        0xa

# %%
print("Base decimal")
print (10)
# Valor 10 en binario
print ("base binaria")
print (0b1010)
# Valor 10 en octal 
print ("Base octal")
print (0o12)
# Valor 10 en hexadecimal 
print ("Base hexadecimal")
print (0xa)
# Out:
# Base decimal
# 10
# base binaria
# 10
# Base octal
# 10
# Base hexadecimal
# 10

# %% [markdown]
# # ¿Qué tan grande puede ser el valor de un entero en Python?
#
# 😳 Podemos declarar enteros tan grandes como la memoria del sistema lo permita.

# %%
variable_3 = 12345678901234567890123456789012345678901234567890123456789012345678901234567890123456789012345678901234567890123456789012345678901234567890123456789
print (variable_3)
print (type(variable_3))
# Out:
# 12345678901234567890123456789012345678901234567890123456789012345678901234567890123456789012345678901234567890123456789012345678901234567890123456789
# <class 'int'>

# %% [markdown]
# # Números con punto flotante
# ## Floating - float
#
# - Son números que tienen parte decimal
# - Pueden ser positivos, negativos o cero.
# - Tienen precisión limitada, no pueden representar números con una cantidad infinita de decimales.
#
#  **R={...,−2.5,−1.5,−0.5,0.5,1.5,2.5,...}**

# %%
# Valor 0.5 Flotante
print (0.5)
print (type(0.5))

# DECLARAR UN VALOR FLOTANTE
variable_4 = 0.100546
print(variable_4)
print (type (variable_4))

variable_7 = float (1)
print(variable_7)
print (type (variable_7))

# LIMITE DE PRECISION FLOTANTE
# Precision de 17 decimales
variable_5 = 0.999999999999999
print(variable_5)
print (type (variable_5))
# Out:
# 0.5
# <class 'float'>
# 0.100546
# <class 'float'>
# 1.0
# <class 'float'>
# 0.999999999999999
# <class 'float'>

# %% [markdown]
# # Operadores aritméticos
# Son símbolos especiales que representan operaciones matemáticas como la suma, la multiplicación y otros cálculos
# ## Operadores aritméticos en Python
# - +: Suma
# - -: Resta
# - ∗ : Multiplicación
# - / : División
# - ∗∗ : Potencia
# - // : División entera
# - % : Módulo o residuo

# %%
# Operadores aritmeticos
a = 10
b = 3
# Suma
print ("suma")
print (a + b)
# Resta
print ("resta")
print (a - b)
# Multiplicacion 
print ("multiplicacion")
print (a * b)
# Division
print ("division")
print (a / b)
# Potencia
print ("Potencia")
print (a ** b)
# Modulo o residuo
print ("modulo o residuo")
print (a % b)
# Division entera
print ("Division entera")
print (a // b)
# Out:
# suma
# 13
# resta
# 7
# multiplicacion
# 30
# division
# 3.3333333333333335
# Potencia
# 1000
# modulo o residuo
# 1
# Division entera
# 3

# %% [markdown]
# # Operadores de comparación
#
# 🤔Son símbolos especiales que permiten comparar dos valores.
#
# ## Operadores de comparación en Python
#
# - <: Estrictamente menor que
# - >: Estrictamente mayor que
# - ==: Estrictamente igual que
# - <=: Menor o igual que
# - >=: Mayor o igual que
# - != : Estrictamente diferente que

# %%
print ("operadores de comparacion con int - float")
entero = 12
flotante = 12.1
print (entero < flotante)
print (entero > flotante)
print (entero == flotante)
print (entero <= flotante)
print (entero >= flotante)
print (entero != flotante)
# Out:
# operadores de comparacion con int - float
# True
# False
# False
# True
# False
# True

# %% [markdown]
# # *FIN DEL LA SESION*
#
#
# ![image.png](attachment:image.png)
